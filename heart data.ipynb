# %%
import pandas as pd

# %%
data=pd.read_csv('C:\\Users\\BIJOY\\Downloads\\heart.csv')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info
# Out:
# <bound method DataFrame.info of      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# ...

# %%
data.shape
# Out:
# (303, 14)

# %%
data.describe() #descriptive statistics
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
data= data.drop_duplicates()
data
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
data.isnull()
# Out:
#        age    sex     cp  trtbps   chol    fbs  restecg  thalachh   exng  \
# 0    False  False  False   False  False  False    False     False  False
# 1    False  False  False   False  False  False    False     False  False
# 2    False  False  False   False  False  False    False     False  False
# 3    False  False  False   False  False  False    False     False  False
# 4    False  False  False   False  False  False    False     False  False
# ..     ...    ...    ...     ...    ...    ...      ...       ...    ...
# 298  False  False  False   False  False  False    False     False  False
# 299  False  False  False   False  False  False    False     False  False
# 300  False  False  False   False  False  False    False     False  False
# 301  False  False  False   False  False  False    False     False  False
# 302  False  False  False   False  False  False    False     False  False
#
#      oldpeak    slp    caa  thall  output
# 0      False  False  False  False   False
# ...

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
data.notnull()
# Out:
#       age   sex    cp  trtbps  chol   fbs  restecg  thalachh  exng  oldpeak  \
# 0    True  True  True    True  True  True     True      True  True     True
# 1    True  True  True    True  True  True     True      True  True     True
# 2    True  True  True    True  True  True     True      True  True     True
# 3    True  True  True    True  True  True     True      True  True     True
# 4    True  True  True    True  True  True     True      True  True     True
# ..    ...   ...   ...     ...   ...   ...      ...       ...   ...      ...
# 298  True  True  True    True  True  True     True      True  True     True
# 299  True  True  True    True  True  True     True      True  True     True
# 300  True  True  True    True  True  True     True      True  True     True
# 301  True  True  True    True  True  True     True      True  True     True
# 302  True  True  True    True  True  True     True      True  True     True
#
#       slp   caa  thall  output
# ...

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data2= data.fillna(value=0)
data2
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
data2.isnull().sum().sum()
# Out:
# 0

# %%
data
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
data2= data.fillna(value=0)
data2
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
data3= data.fillna(method='pad')
data3
# Out:
# C:\Users\BIJOY\AppData\Local\Temp\ipykernel_9864\2695276835.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data3= data.fillna(method='pad')
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# ...

# %%
#filling null values with the next value
data4= data.fillna(method='bfill')
data4
# Out:
# C:\Users\BIJOY\AppData\Local\Temp\ipykernel_9864\1171003154.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data4= data.fillna(method='bfill')
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
#detect the outliers using IQR
data2.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
data2.drop(['age'], axis=1, inplace=True)
data2.columns
# Out:
# Index(['sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh', 'exng',
#        'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
Q1= data2.quantile(0.25)
Q2= data2.quantile(0.75)
IQR=Q2-Q1
print(IQR)
# Out:
# sex          1.00
# cp           2.00
# trtbps      20.00
# chol        63.75
# fbs          0.00
# restecg      1.00
# thalachh    32.75
# exng         1.00
# oldpeak      1.60
# slp          1.00
# caa          1.00
# thall        1.00
# output       1.00
# dtype: float64

# %%
data2=data2[~((data2<(Q1-1.5*IQR))|(data2>(Q2+1.5*IQR))).any(axis=1)]
data2
# Out:
#      sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  caa  \
# 1      1   2     130   250    0        1       187     0      3.5    0    0
# 2      0   1     130   204    0        0       172     0      1.4    2    0
# 3      1   1     120   236    0        1       178     0      0.8    2    0
# 4      0   0     120   354    0        1       163     1      0.6    2    0
# 5      1   0     140   192    0        1       148     0      0.4    1    0
# ..   ...  ..     ...   ...  ...      ...       ...   ...      ...  ...  ...
# 296    0   0     124   197    0        1       136     1      0.0    1    0
# 298    0   0     140   241    0        1       123     1      0.2    1    0
# 299    1   3     110   264    0        1       132     0      1.2    1    0
# 301    1   0     130   131    0        1       115     1      1.2    1    1
# 302    0   1     130   236    0        0       174     0      0.0    1    1
#
#      thall  output
# 1        2       1
# ...

# %%
data2.describe()
# Out:
#               sex          cp      trtbps        chol    fbs     restecg  \
# count  228.000000  228.000000  228.000000  228.000000  228.0  228.000000
# mean     0.675439    0.942982  128.671053  242.372807    0.0    0.548246
# std      0.469241    1.020190   15.349142   44.329827    0.0    0.516125
# min      0.000000    0.000000   94.000000  131.000000    0.0    0.000000
# 25%      0.000000    0.000000  120.000000  209.750000    0.0    0.000000
# 50%      1.000000    1.000000  130.000000  239.000000    0.0    1.000000
# 75%      1.000000    2.000000  140.000000  269.250000    0.0    1.000000
# max      1.000000    3.000000  170.000000  360.000000    0.0    2.000000
#
#          thalachh        exng     oldpeak         slp        caa       thall  \
# count  228.000000  228.000000  228.000000  228.000000  228.00000  228.000000
# mean   151.070175    0.315789    0.946053    1.451754    0.47807    2.315789
# std     22.492963    0.465852    1.035422    0.587945    0.69893    0.560299
# ...
